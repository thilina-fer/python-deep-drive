# %% [markdown]
# # Python Sets

# %% [markdown]
# - Sets are used to store multiple items in a single variable.
# - Set is a unordered
# - changeable (you can add or remove items but you can’t change or update an item that is already in a set)
# - does not allow duplicate values.
# - Set items are not indexed, so you cannot access them by position like in lists or tuples.
# - Python sets are mutable.

# %%
sports = {"tennis", "cricket", "football"}
print(sports) 
print(type(sports))
# Out:
# {'tennis', 'cricket', 'football'}
# <class 'set'>

# %% [markdown]
# # Length of a set

# %% [markdown]
# - To determine how many items a set has, use the len() function.

# %%
this_set = {"apple", "banana", "cherry"}
print(len(this_set))
# Out:
# 3

# %% [markdown]
# # Property of a sets

# %% [markdown]
# - A set can contain different data types

# %%
set_1 = {"abc", 34, True, 40, "male"}
print(set_1)
# Out:
# {'male', True, 34, 40, 'abc'}

# %% [markdown]
# # Access Items on a set

# %% [markdown]
# - Once a set is created, you cannot change its items, but you can add new items (not like tuples). Therefore Sets are mutable.

# %%
fruits = {"apple", "banana", "cherry"}

for x in fruits:
    print(x)
# Out:
# apple
# banana
# cherry

# %%
fruits = {"apple", "banana", "cherry"}
print("banana" in fruits)
# Out:
# True

# %% [markdown]
# # Add items on set

# %% [markdown]
# - Python sets are mutable in the sense that you can add new elements after creation using methods like **.add()** or **.update()**.

# %%
sports = {"tennis", "cricket", "football"}
sports.add("soccer") 
print(sports) 
sports.update(["basketball", "volleyball"]) 
print(sports)
# Out:
# {'tennis', 'cricket', 'football', 'soccer'}
# {'football', 'soccer', 'cricket', 'tennis', 'volleyball', 'basketball'}

# %% [markdown]
# # Removing items on sets

# %% [markdown]
# - You can also remove items using methods like .remove() (raises an error if the item isn’t found) or .discard() (no error if the item isn’t present).

# %%
sports = {"tennis", "cricket", "football"}
sports.remove("cricket")
print(sports)
# Out:
# {'tennis', 'football'}

# %%
set_1 = {1,5,8,9,3}
set_2 = {2,3,6,7}
list_1 = [1,2,3,4,5,6]

print(set_1.union(set_2))
print(set_1 | set(list_1))
print(set_1 | set_2)

print(set_1.intersection(set_2))
print(set_1 & set_2)
print(set_1.intersection(set(list_1)))
print(set_1 & set(list_1))
# Out:
# {1, 2, 3, 5, 6, 7, 8, 9}
# {1, 2, 3, 4, 5, 6, 8, 9}
# {1, 2, 3, 5, 6, 7, 8, 9}
# {3}
# {3}
# {1, 3, 5}
# {1, 3, 5}
