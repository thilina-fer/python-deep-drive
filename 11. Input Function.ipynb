# %% [markdown]
# # Input Function

# %% [markdown]
# - In Python, the input() function always returns the data as a String (str), even if the user types a number.

# %%
num = input("Enter a number: ")
print("You entered:", num , type(num))
# Out:
# You entered: 5 <class 'str'>

# %%
num_2 = int(input("Enter another number: "))
print("You entered:", num_2 , type(num_2))
# Out:
# You entered: 4 <class 'int'>
