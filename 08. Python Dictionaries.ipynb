# %% [markdown]
# # Mapping Data Type: Python Dictionaries

# %% [markdown]
# - Dictionaries are used to store data values in key:value pairs.
# - A dictionary is a collection which is ordered, changeable and does not allow duplicates.
# - As of Python version 3.7, dictionaries are ordered. In Python 3.6 and earlier, dictionaries are unordered.
# - Dictionaries are written with curly brackets, and have keys and values:

# %%
this_dict = {
"name": "Sugar",
"weight": "1kg",
"price": 130.35
}
print(this_dict)
# Out:
# {'name': 'Sugar', 'weight': '1kg', 'price': 130.35}

# %% [markdown]
# - Dictionary items are ordered, changeable, and does not allow duplicates.
# - Dictionary items are presented in key:value pairs, and can be referred to by using the key name.

# %%
this_dict = {
"name": "Sugar",
"weight": "1kg",
"price": 130.35
}
print(this_dict["price"])
# Out:
# 130.35

# %% [markdown]
# - Dictionaries cannot have two items with the same key: Duplicate values will overwrite existing values:

# %%
this_dict = {
"name": "Sugar",
"weight": "1kg",
"price": 130.35,
"price": 128.15
}
print(this_dict)
print(this_dict["price"])
# Out:
# {'name': 'Sugar', 'weight': '1kg', 'price': 128.15}
# 128.15

# %% [markdown]
# - Strings, Numbers, Booleans, Lists, Tuples, Sets, Other dictionaries, Custom objects:

# %%
my_dict = {
"name": "John",
"age": 30,
"is_student": False,
"grades": [85, 92, 78],
"coordinates": (12.34, 56.78),
"preferences": {"color": "blue", "food": "pizza"}
}
print(my_dict)
# Out:
# {'name': 'John', 'age': 30, 'is_student': False, 'grades': [85, 92, 78], 'coordinates': (12.34, 56.78), 'preferences': {'color': 'blue', 'food': 'pizza'}}

# %% [markdown]
# **Dictionary keys must be immutable (to have a constant hash value).**
#
# ❌ You cannot use the following as dictionary keys:
# - list (e.g., [1, 2])
# - dict (e.g., {"a": 1})
# - set (e.g., {1, 2, 3})
#
# ✅ You can use these types as dictionary keys:
# - int, float, str, bool
# - tuple (only if it contains only hashable types)
# - frozenset (immutable version of set)

# %% [markdown]
# # Accessing items on Ditionary

# %% [markdown]
# - You can access the items of a dictionary by referring to its key name, inside square brackets:

# %%
this_dict = {
"name": "Sugar",
"weight": "1kg",
"price": 130.35
}
x = this_dict["price"]
print(x)

x = this_dict.get("weight")
print(x)
# Out:
# 130.35
# 1kg

# %% [markdown]
# # Update Dictionary values

# %%
this_dict = {
"name": "Sugar",
"weight": "1kg",
"price": 130.35
}
this_dict.update({"name": "Salt", "price": 112.80})
print(this_dict)
# Out:
# {'name': 'Salt', 'weight': '1kg', 'price': 112.8}

# %% [markdown]
# # Adding Items on Ditionary

# %% [markdown]
# - Adding an item to the dictionary is done by using a new index key and assigning a value to it

# %%
this_dict = {
"name": "Sugar",
"weight": "1kg",
"price": 130.35
}
this_dict["color"] = "red"
print(this_dict)
# Out:
# {'name': 'Sugar', 'weight': '1kg', 'price': 130.35, 'color': 'red'}

# %% [markdown]
# # Removing Items on Ditionary

# %% [markdown]
# - There are several methods to remove items from a dictionary:
# - The pop() method removes the item with the specified key name:

# %%
this_dict = {
"name": "Sugar",
"weight": "1kg",
"price": 130.35
}
this_dict.pop("price")
print(this_dict)
# Out:
# {'name': 'Sugar', 'weight': '1kg'}

# %% [markdown]
# - The popitem() method removes the last inserted item (in versions before 3.7, a random item is removed instead):

# %%
this_dict = {
"name": "Sugar",
"weight": "1kg",
"price": 130.35
}
this_dict.popitem()
print(this_dict)
# Out:
# {'name': 'Sugar', 'weight': '1kg'}

# %% [markdown]
# - The del keyword removes the item with the specified key name:

# %%
this_dict = {
"name": "Sugar",
"weight": "1kg",
"price": 130.35
}
del this_dict["price"] 
print(this_dict)
# Out:
# {'name': 'Sugar', 'weight': '1kg'}

# %% [markdown]
# - The del keyword can also delete the dictionary completely:

# %%
this_dict = {
"name": "Sugar",
"weight": "1kg",
"price": 130.35
}

del this_dict
print(this_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 8
#       4 "price": 130.35
#       5 }
#       6
#       7 del this_dict
# ----> 8 print(this_dict)
#
# NameError: name 'this_dict' is not defined

# %% [markdown]
# - The clear() method empties the dictionary:

# %%
this_dict = {
"name": "Sugar",
"weight": "1kg",
"price": 130.35
}
this_dict.clear()
print(this_dict)
# Out:
# {}

# %% [markdown]
# # Copy a Dictionary

# %% [markdown]
# - You cannot copy a dictionary simply by typing dict2 = dict1, because: dict2 will only be a reference to dict1,and changes made in dict1 will automatically also be made in dict2.
# - There are ways to make a copy, one way is to use the built-in Dictionary method copy().

# %%
# method 1
this_dict = {
"name": "Sugar",
"weight": "1kg",
"price": 130.35
}
my_dict = this_dict.copy()
print(my_dict)

# method 2
my_dict = dict(this_dict)
print(my_dict)
# Out:
# {'name': 'Sugar', 'weight': '1kg', 'price': 130.35}
# {'name': 'Sugar', 'weight': '1kg', 'price': 130.35}

# %% [markdown]
# # Nested Dictionaries

# %% [markdown]
# Nested dictionaries in Python refer to dictionaries that are contained within another dictionary as values.

# %%
students = {
    "student1": {
        "name": "Amal",
        "age": 15,
        "city": "Colombo"
    },
    "student2": {
        "name": "Nimal",
        "age": 16,
        "city": "Kandy"
    },
    "student3": {
        "name": "Kamal",
        "age": 15,
        "city": "Galle"
    }
}

# Accessing Items
print(students["student2"]["city"])

# Adding Items
students["student4"] = {
    "name": "Nimal",
    "age": 16,
    "city": "Kandy"
}
print(students)
# Out:
# Kandy
# {'student1': {'name': 'Amal', 'age': 15, 'city': 'Colombo'}, 'student2': {'name': 'Nimal', 'age': 16, 'city': 'Kandy'}, 'student3': {'name': 'Kamal', 'age': 15, 'city': 'Galle'}, 'student4': {'name': 'Nimal', 'age': 16, 'city': 'Kandy'}}
